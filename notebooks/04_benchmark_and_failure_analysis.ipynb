# %% [markdown]
# # 04 - Benchmark and failure analysis
#
# This notebook runs repeated benchmarks and examines success, experiment counts, and failure categories.

# %%
from asd_agent.benchmark import run_benchmark

rows = run_benchmark(repetitions=20, output_dir="../results/notebook_04/benchmark", budget=20)
rows[:3]

# %%
from collections import Counter

Counter((row["method"], row["failure_category"]) for row in rows)

# %% [markdown]
# For LLM variability, rerun the benchmark with `methods=['llm']` after setting `OPENAI_API_KEY` and `OPENAI_MODEL`.
